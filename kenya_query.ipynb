# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('acled-version-7-all-africa-1997-2016-dyadic-file-xlsx-2.xls')

# %%
data.head()
# Out:
#    GWNO EVENT_ID_CNTY  EVENT_ID_NO_CNTY EVENT_DATE  YEAR  TIME_PRECISION  \
# 0   615          1ALG                 1 1997-01-04  1997               1
# 1   615          2ALG                 2 1997-01-05  1997               1
# 2   615          3ALG                 3 1997-01-06  1997               1
# 3   615          4ALG                 4 1997-01-07  1997               1
# 4   615          5ALG                 5 1997-01-11  1997               1
#
#                    EVENT_TYPE                    ACTOR1 ALLY_ACTOR_1  INTER1  \
# 0  Violence against civilians  GIA: Armed Islamic Group          NaN       2
# 1  Violence against civilians  GIA: Armed Islamic Group          NaN       2
# 2  Violence against civilians  GIA: Armed Islamic Group          NaN       2
# 3             Remote violence  GIA: Armed Islamic Group          NaN       2
# 4  Violence against civilians  GIA: Armed Islamic Group          NaN       2
#
# ...

# %%
kenya = data[data['COUNTRY'] == 'Kenya']
kenya.shape
# Out:
# (5311, 36)

# %%
violence_kenya = kenya.to_csv('Violence In Kenya.csv')
